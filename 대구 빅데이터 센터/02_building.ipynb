# %% [markdown]
# # 1. 건물 데이터 test

# %%
import geopandas as gpd
import fiona

# %%
gdf = gpd.read_file("GIS건물일반집합정보_500.gpkg")
gdf.columns
# Out:
# Index(['id', 'count', '건축물용도코드_count_01000', '건축물용도코드_count_01001',
#        '건축물용도코드_count_01003', '건축물용도코드_count_02000', '건축물용도코드_count_03000',
#        '건축물용도코드_count_03100', '건축물용도코드_count_04000', '건축물용도코드_count_05000',
#        '건축물용도코드_count_06000', '건축물용도코드_count_07000', '건축물용도코드_count_08000',
#        '건축물용도코드_count_09000', '건축물용도코드_count_10000', '건축물용도코드_count_11000',
#        '건축물용도코드_count_12000', '건축물용도코드_count_13000', '건축물용도코드_count_14000',
#        '건축물용도코드_count_15000', '건축물용도코드_count_16000', '건축물용도코드_count_17000',
#        '건축물용도코드_count_18000', '건축물용도코드_count_19000', '건축물용도코드_count_20000',
#        '건축물용도코드_count_21000', '건축물용도코드_count_22000', '건축물용도코드_count_23000',
#        '건축물용도코드_count_24000', '건축물용도코드_count_25000', '건축물용도코드_count_26000',
#        '건축물용도코드_count_27000', '건축물용도코드_count_29000', '건축물용도코드_count_30000',
#        '건축물용도코드_count_31000', '건축물용도코드_count_JY', '건축물용도코드_count_Z3000',
# ...

# %%
print(gdf.iloc[1])
# Out:
# id                                                                    70
# count                                                                NaN
# 건축물용도코드_count_01000                                                  NaN
# 건축물용도코드_count_01001                                                  NaN
# 건축물용도코드_count_01003                                                  NaN
#                                              ...
# 총주차장면적_sum                                                           NaN
# 총주차장면적_mean                                                          NaN
# 총주차장면적_min                                                           NaN
# 총주차장면적_max                                                           NaN
# geometry               MULTIPOLYGON (((1077057.173324328 1745639.5462...
# Name: 1, Length: 83, dtype: object

# %%
gdf.head()
# Out:
#    id  count  건축물용도코드_count_01000  건축물용도코드_count_01001  건축물용도코드_count_01003  \
# 0  69    NaN                  NaN                  NaN                  NaN
# 1  70    NaN                  NaN                  NaN                  NaN
# 2  71    NaN                  NaN                  NaN                  NaN
# 3  72   17.0                  6.0                  NaN                  NaN
# 4  73   10.0                  1.0                  NaN                  NaN
#
#    건축물용도코드_count_02000  건축물용도코드_count_03000  건축물용도코드_count_03100  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  2.0                  NaN
#
#    건축물용도코드_count_04000  건축물용도코드_count_05000  ...  지하층수_max  총주차수_sum  \
# ...
